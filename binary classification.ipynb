# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('hotel.csv')
display(hotel.head())
print(hotel.shape)

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - makes sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]
# (119390, 32)

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256,activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation="sigmoid")
    
])

# %%
model.compile(
       optimizer="adam",
       loss="binary_crossentropy",
       metrics=["binary_accuracy"])

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/200
# 175/175 [==============================] - 4s 16ms/step - loss: 0.5515 - binary_accuracy: 0.7336 - val_loss: 0.4304 - val_binary_accuracy: 0.7989
# Epoch 2/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4341 - binary_accuracy: 0.7931 - val_loss: 0.3993 - val_binary_accuracy: 0.8152
# Epoch 3/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4113 - binary_accuracy: 0.8064 - val_loss: 0.3914 - val_binary_accuracy: 0.8179
# Epoch 4/200
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4029 - binary_accuracy: 0.8115 - val_loss: 0.3869 - val_binary_accuracy: 0.8227
# Epoch 5/200
# 175/175 [==============================] - 2s 14ms/step - loss: 0.3991 - binary_accuracy: 0.8141 - val_loss: 0.3876 - val_binary_accuracy: 0.8228
# Epoch 6/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3931 - binary_accuracy: 0.8173 - val_loss: 0.3820 - val_binary_accuracy: 0.8255
# Epoch 7/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3875 - binary_accuracy: 0.8198 - val_loss: 0.3810 - val_binary_accuracy: 0.8255
# Epoch 8/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3894 - binary_accuracy: 0.8176 - val_loss: 0.3762 - val_binary_accuracy: 0.8287
# Epoch 9/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3807 - binary_accuracy: 0.8225 - val_loss: 0.3740 - val_binary_accuracy: 0.8288
# Epoch 10/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3762 - binary_accuracy: 0.8247 - val_loss: 0.3732 - val_binary_accuracy: 0.8290
# Epoch 11/200
# 175/175 [==============================] - 3s 15ms/step - loss: 0.3766 - binary_accuracy: 0.8246 - val_loss: 0.3718 - val_binary_accuracy: 0.8291
# Epoch 12/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3764 - binary_accuracy: 0.8248 - val_loss: 0.3694 - val_binary_accuracy: 0.8302
# Epoch 13/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3725 - binary_accuracy: 0.8262 - val_loss: 0.3672 - val_binary_accuracy: 0.8315
# Epoch 14/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3667 - binary_accuracy: 0.8296 - val_loss: 0.3677 - val_binary_accuracy: 0.8328
# Epoch 15/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3679 - binary_accuracy: 0.8291 - val_loss: 0.3672 - val_binary_accuracy: 0.8325
# Epoch 16/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3683 - binary_accuracy: 0.8293 - val_loss: 0.3645 - val_binary_accuracy: 0.8314
# Epoch 17/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3656 - binary_accuracy: 0.8300 - val_loss: 0.3643 - val_binary_accuracy: 0.8338
# Epoch 18/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3598 - binary_accuracy: 0.8341 - val_loss: 0.3631 - val_binary_accuracy: 0.8360
# Epoch 19/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3612 - binary_accuracy: 0.8319 - val_loss: 0.3599 - val_binary_accuracy: 0.8359
# Epoch 20/200
# 175/175 [==============================] - 3s 16ms/step - loss: 0.3571 - binary_accuracy: 0.8354 - val_loss: 0.3598 - val_binary_accuracy: 0.8349
# Epoch 21/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3578 - binary_accuracy: 0.8350 - val_loss: 0.3602 - val_binary_accuracy: 0.8354
# Epoch 22/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3550 - binary_accuracy: 0.8376 - val_loss: 0.3589 - val_binary_accuracy: 0.8373
# Epoch 23/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3527 - binary_accuracy: 0.8367 - val_loss: 0.3573 - val_binary_accuracy: 0.8372
# Epoch 24/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3559 - binary_accuracy: 0.8357 - val_loss: 0.3557 - val_binary_accuracy: 0.8360
# Epoch 25/200
# 175/175 [==============================] - 3s 17ms/step - loss: 0.3533 - binary_accuracy: 0.8367 - val_loss: 0.3559 - val_binary_accuracy: 0.8369
# Epoch 26/200
# 175/175 [==============================] - 3s 20ms/step - loss: 0.3522 - binary_accuracy: 0.8361 - val_loss: 0.3545 - val_binary_accuracy: 0.8379
# Epoch 27/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3496 - binary_accuracy: 0.8377 - val_loss: 0.3577 - val_binary_accuracy: 0.8370
# Epoch 28/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3521 - binary_accuracy: 0.8372 - val_loss: 0.3539 - val_binary_accuracy: 0.8398
# Epoch 29/200
# 175/175 [==============================] - 3s 20ms/step - loss: 0.3483 - binary_accuracy: 0.8407 - val_loss: 0.3526 - val_binary_accuracy: 0.8395
# Epoch 30/200
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3457 - binary_accuracy: 0.8413 - val_loss: 0.3534 - val_binary_accuracy: 0.8396
# Epoch 31/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3449 - binary_accuracy: 0.8404 - val_loss: 0.3538 - val_binary_accuracy: 0.8377
# Epoch 32/200
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3433 - binary_accuracy: 0.8413 - val_loss: 0.3518 - val_binary_accuracy: 0.8398
# Epoch 33/200
# 175/175 [==============================] - 4s 22ms/step - loss: 0.3446 - binary_accuracy: 0.8412 - val_loss: 0.3523 - val_binary_accuracy: 0.8415
# Epoch 34/200
# 175/175 [==============================] - 3s 19ms/step - loss: 0.3407 - binary_accuracy: 0.8417 - val_loss: 0.3541 - val_binary_accuracy: 0.8389

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# <AxesSubplot:title={'center':'Accuracy'}>
